# %%
# Navigate to the root of the project and import necessary libraries
from hydra import initialize, compose
initialize(config_path="../confs", job_name="notebook")

import sys
import os
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../src"))
# We change the working directory to the root of the project
# Run this only once
root_path = Path.cwd().parent
os.chdir(root_path)
sys.path.append(root_path / "src")
# Out:
# /tmp/ipykernel_2066826/1263814139.py:3: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   initialize(config_path="../confs", job_name="notebook")

# %%
from hydra.utils import instantiate
import os
os.environ["HYDRA_FULL_ERROR"] = "1"

import logging
logging.basicConfig(level=logging.INFO)

cfg = compose(config_name="config_2")
# Instantiate the model
model = instantiate(cfg.flow_model.model)

from torchscan import summary
channels, H, W = 32, 224, 224

summary(model.conv_features, (channels, H, W), receptive_field=True)
# Out:
# /home/ids/wauquiez/anaconda3/envs/flow_matching/lib/python3.12/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'config_2': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# ____________________________________________________________________________________________________________
# Layer                        Type                  Output Shape              Param #         Receptive field
# ============================================================================================================
# unet                         UNet                  (-1, 32, 224, 224)        0               45
# ├─pre                        Sequential            (-1, 32, 224, 224)        0               45
# |    └─0                     Conv2d                (-1, 32, 224, 224)        9,248           45
# |    └─1                     ReLU                  (-1, 32, 224, 224)        0               43
# |    └─2                     Conv2d                (-1, 32, 224, 224)        9,248           43
# |    └─3                     ReLU                  (-1, 32, 224, 224)        0               41
# ├─inner                      UNet                  (-1, 32, 112, 112)        0               41
# |    └─pre                   Sequential            (-1, 32, 112, 112)        0               41
# |    |    └─0                Conv2d                (-1, 32, 112, 112)        9,248           41
# |    |    └─1                ReLU                  (-1, 32, 112, 112)        0               39
# |    |    └─2                Conv2d                (-1, 32, 112, 112)        9,248           39
# |    |    └─3                ReLU                  (-1, 32, 112, 112)        0               37
# |    └─inner                 UNet                  (-1, 32, 56, 56)          0               37
# |    |    └─pre              Sequential            (-1, 32, 56, 56)          0               37
# |    |    |    └─0           Conv2d                (-1, 32, 56, 56)          9,248           37
# |    |    |    └─1           ReLU                  (-1, 32, 56, 56)          0               35
# |    |    |    └─2           Conv2d                (-1, 32, 56, 56)          9,248           35
# |    |    |    └─3           ReLU                  (-1, 32, 56, 56)          0               33
# |    |    └─inner            UNet                  (-1, 32, 28, 28)          0               33
# |    |    |    └─pre         Sequential            (-1, 32, 28, 28)          0               33
# |    |    |    |    └─0      Conv2d                (-1, 32, 28, 28)          9,248           33
# |    |    |    |    └─1      ReLU                  (-1, 32, 28, 28)          0               31
# |    |    |    |    └─2      Conv2d                (-1, 32, 28, 28)          9,248           31
# |    |    |    |    └─3      ReLU                  (-1, 32, 28, 28)          0               29
# |    |    |    └─inner       UNet                  (-1, 32, 14, 14)          0               29
# |    |    |    |    └─pre    Sequential            (-1, 32, 14, 14)          0               29
# |    |    |    |    |        Conv2d                (-1, 32, 14, 14)          9,248           29
# |    |    |    |    |        ReLU                  (-1, 32, 14, 14)          0               27
# |    |    |    |    |        Conv2d                (-1, 32, 14, 14)          9,248           27
# |    |    |    |    |        ReLU                  (-1, 32, 14, 14)          0               25
# |    |    |    |    └─inn    Sequential            (-1, 32, 7, 7)            0               25
# |    |    |    |    |        Conv2d                (-1, 32, 7, 7)            9,248           25
# |    |    |    |    |        ReLU                  (-1, 32, 7, 7)            0               23
# |    |    |    |    |        Conv2d                (-1, 32, 7, 7)            9,248           23
# |    |    |    |    |        ReLU                  (-1, 32, 7, 7)            0               21
# |    |    |    |    └─pos    Sequential            (-1, 32, 14, 14)          0               21
# |    |    |    |    |        Conv2d                (-1, 32, 14, 14)          18,464          21
# |    |    |    |    |        ReLU                  (-1, 32, 14, 14)          0               19
# |    |    |    |    |        Conv2d                (-1, 32, 14, 14)          9,248           19
# |    |    |    |    |        ReLU                  (-1, 32, 14, 14)          0               17
# |    |    |    └─post        Sequential            (-1, 32, 28, 28)          0               17
# |    |    |    |    └─0      Conv2d                (-1, 32, 28, 28)          18,464          17
# |    |    |    |    └─1      ReLU                  (-1, 32, 28, 28)          0               15
# |    |    |    |    └─2      Conv2d                (-1, 32, 28, 28)          9,248           15
# |    |    |    |    └─3      ReLU                  (-1, 32, 28, 28)          0               13
# |    |    └─post             Sequential            (-1, 32, 56, 56)          0               13
# |    |    |    └─0           Conv2d                (-1, 32, 56, 56)          18,464          13
# |    |    |    └─1           ReLU                  (-1, 32, 56, 56)          0               11
# |    |    |    └─2           Conv2d                (-1, 32, 56, 56)          9,248           11
# |    |    |    └─3           ReLU                  (-1, 32, 56, 56)          0               9
# |    └─post                  Sequential            (-1, 32, 112, 112)        0               9
# |    |    └─0                Conv2d                (-1, 32, 112, 112)        18,464          9
# |    |    └─1                ReLU                  (-1, 32, 112, 112)        0               7
# |    |    └─2                Conv2d                (-1, 32, 112, 112)        9,248           7
# |    |    └─3                ReLU                  (-1, 32, 112, 112)        0               5
# ├─post                       Sequential            (-1, 32, 224, 224)        0               5
# |    └─0                     Conv2d                (-1, 32, 224, 224)        18,464          5
# |    └─1                     ReLU                  (-1, 32, 224, 224)        0               3
# |    └─2                     Conv2d                (-1, 32, 224, 224)        9,248           3
# |    └─3                     ReLU                  (-1, 32, 224, 224)        0               1
# ============================================================================================================
# Trainable params: 249,536
# Non-trainable params: 0
# Total params: 249,536
# ------------------------------------------------------------------------------------------------------------
# Model size (params + buffers): 0.95 Mb
# Framework & CUDA overhead: 0.00 Mb
# Total RAM usage: 0.95 Mb
# ------------------------------------------------------------------------------------------------------------
# Floating Point Operations on forward: 6.17 GFLOPs
# Multiply-Accumulations on forward: 3.08 GMACs
# Direct memory accesses on forward: 3.11 GDMAs
# ____________________________________________________________________________________________________________
# /home/ids/wauquiez/anaconda3/envs/flow_matching/lib/python3.12/site-packages/torchscan/process/memory.py:32: UserWarning: raised: [Errno 2] No such file or directory: 'nvidia-smi'. Assuming no GPU is available.
#   warnings.warn(f"raised: {e}. Assuming no GPU is available.")
